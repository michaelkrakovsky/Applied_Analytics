# %%
from fastai.vision import *
import os                             # Use this to make folders (For Data) in Windows

# %%
# The class names of all the data files.
classes = ['afghan_war', 'civil_war', 'gulf_war', 'korean_war', 'lebonon_war', 'vietnam_war', 'ww1', 'ww2']

# %%
# Download all the files into the respective repositories.
path_links = './data_links/'
path_dest = './data/'

# %%
# Only need to run this once
"""
for i in classes:
    file_name = path_links + i + '.txt'                    # Get the textfile containing the links to the images.
    file_name = Path(file_name)
    dest = path_dest + i                                   # Download the images into a folder resembling the class name.
    dest = Path(dest)
    if (not os.path.exists(dest) and os.name == 'nt'):     # Create a folder if it does not exist. (Only for Windows)                           
        os.makedirs(dest)
    else:
        raise ValueError("Directory does not exist.")
    download_images(file_name, dest, max_pics=300)
    print(i + ": Successfully Downloaded.")
"""
# Out:
# afghan_war: Successfully Downloaded.
# civil_war: Successfully Downloaded.
# gulf_war: Successfully Downloaded.
# korean_war: Successfully Downloaded.
# lebonon_war: Successfully Downloaded.
# vietnam_war: Successfully Downloaded.
# ww1: Successfully Downloaded.
# ww2: Successfully Downloaded.

# %%
# Perform light clean on images.
for c in classes:
    print("Verifying Images In: {}".format(c))
    final_dest = Path(path_dest + c)
    verify_images(final_dest, delete=True, max_size=500)
# Out:
# Verifying Images In: afghan_war
# Verifying Images In: civil_war
# Verifying Images In: gulf_war
# Verifying Images In: korean_war
# Verifying Images In: lebonon_war
# Verifying Images In: vietnam_war
# Verifying Images In: ww1
# Verifying Images In: ww2

# %%
# Organise the data into proper folders.
np.random.seed(42)
data = ImageDataBunch.from_folder(path_dest, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4, bs=12).normalize(imagenet_stats)

# %%
# Display some of the data... looks like it will require some scrubbing.
data.show_batch(rows=3, figsize=(7,8))

# %%
# Display additional parameters. Is this enough data?
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['afghan_war',
#   'civil_war',
#   'gulf_war',
#   'korean_war',
#   'lebonon_war',
#   'vietnam_war',
#   'ww1',
#   'ww2'],
#  8,
#  1648,
#  412)

# %%
# Train with resnet34
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.920541</td>
#       <td>2.413059</td>
#       <td>0.701456</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.449908</td>
#       <td>1.991857</td>
#       <td>0.662621</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.931142</td>
#       <td>1.766711</td>
#       <td>0.650485</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.676370</td>
#       <td>1.748688</td>
#       <td>0.631068</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>
